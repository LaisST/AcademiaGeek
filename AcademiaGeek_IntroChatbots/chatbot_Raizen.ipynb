# %% [markdown]
# ##Chatbot Raízen

# %% [markdown]
# ###Bibliotecas

# %%
# !pip install chatterbot==1.0.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 24.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.5/269.5 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.5/515.5 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.6/270.6 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.2.19-cp39-cp39-linux_x86_64.whl size=1157842 sha256=1bb443b955705f6db0a871a74c236d296aa7a7b075dd6942e49e9666669a0487
# ...

# %%
from chatterbot import ChatBot

chatbot = ChatBot("Raiza")

from chatterbot.trainers import ListTrainer

import re
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
f = open('/content/saudacao.txt','r')

conversation = []

for line in f:
  m = re.search('(Q:|A:)?(.+)', line) 
  if m: 
    conversation.append(m.groups()[1]) 

print(conversation)
# Out:
# ['Oi', 'Olá!', 'eai', 'Oi, tudo bem?', 'opa', 'Olá! tudo bem?', 'Bom dia', 'Bom dia, como posso te ajudar?', 'Boa tarde', 'Boa tarde, como posso te ajudar?', 'Boa noite', 'Boa noite, como posso te ajudar?', 'boa noite', 'Boa noite, como posso te ajudar?']

# %% [markdown]
# ###Treinando o chatbot

# %%
trainer = ListTrainer(chatbot)
trainer.train(conversation)
# Out:
# List Trainer: [####################] 100%

# %%
f = open('/content/raizen.txt','r')

conversation = []

for line in f:
  m = re.search('(Q:|A:)?(.+)', line) 
  if m: 
    conversation.append(m.groups()[1]) 

print(conversation)
# Out:
# ['Como surgiu a Raizen', 'A Raízen é uma joint venture, criada a partir da união de parte dos negócios da Shell e da Cosan. As unidades da Cosan responsáveis pelas atividades de produção de açúcar e etanol e cogeração de energia foram integradas na nova empresa.', 'Qual o propósito da raizen', 'O objetivo da Raízen é realizar de forma eficiente, responsável e lucrativa as atividades de distribuição de combustíveis e de agroindústria, incluindo a produção e comercialização de açúcar e etanol, a cogeração de energia e outros negócios específicos, além de participar do desenvolvimento de biocombustíveis', 'Qual ano de fundação da Raizen', 'A raizen foi fundada em 2011.', 'Quem é o presidente da Raizen', 'O presidente da Raízen é o Ricardo Mussa.', 'Quantas pessoas trabalham na raizen', 'Pouco mais de 40 mil pessoas', 'Quais os segmentos de negocio da raizen', 'A Raízen atende diversos segmentos – transporte de cargas e passageiros, agrícola, minerador, ferroviário e industrial – e inves
# ...

# %%
trainer = ListTrainer(chatbot)
trainer.train(conversation)
# Out:
# List Trainer: [####################] 100%

# %%
while True:
  pergunta = input("👤Usuário: ")
  resposta = chatbot.get_response(pergunta)
  if float(resposta.confidence) > 0.5:
    print("🤖Raíza: ", resposta)
  else:
    print("🤖Raíza: Ainda não sei responder está pergunta, estou aprendendo")
