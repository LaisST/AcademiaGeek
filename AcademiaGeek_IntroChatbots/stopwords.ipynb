# %% [markdown]
# ## StopWords

# %% [markdown]
# ### Bibliotecas

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.2.0)

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from string import punctuation

import nltk

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ###Declarando sentenças

# %%
example_sent = "Olá Lais, tudo bem? Estou com problemas com a minha VPN"

# %% [markdown]
# ###Declarando as stopwords

# %%
stop_words = set(stopwords.words('portuguese')+list(punctuation))

# %% [markdown]
# ###Filtrar Sentenças

# %%
word_tokens = word_tokenize(example_sent)
print(stop_words)
# Out:
# {'-', 'houvessem', '}', ':', 'tivesse', 'me', 'vocês', 'forem', 'estive', 'nossos', 'às', 'isso', 'isto', 'teríamos', 'já', 'num', 'elas', 'estivemos', 'no', '$', 'te', 'das', 'eles', 'pelas', 'houve', 'dela', 'seriam', 'houveria', 'se', 'houverá', 'nos', 'estivéramos', 'do', '|', 'o', 'era', 'estão', 'fomos', 'esse', 'nossa', 'houveriam', 'você', 'ao', '&', 'houverei', 'houveram', 'dele', ';', 'sejamos', 'tém', 'aos', 'houvéssemos', 'teu', 'fôssemos', '(', '>', 'tivemos', 'essas', 'será', 'tua', 'hão', 'nas', ')', 'meu', 'há', 'houver', 'hajam', 'meus', '~', 'for', 'houveríamos', 'estiverem', 'fui', 'havemos', 'estejam', 'suas', 'sem', '[', 'eu', 'formos', 'à', 'pelo', 'tivéssemos', 'para', 'terá', 'aqueles', 'houvesse', '/', 'tuas', 'tenham', '^', 'pelos', 'estivéssemos', 'terão', '"', 'estavam', '#', 'a', 'tínhamos', 'tiveram', 'somos', 'seus', 'tenhamos', 'ou', 'esses', 'um', 'pela', 'deles', 'de', 'haja', 'seremos', 'houverem', 'teus', 'esteve', 'haver', ']', 'houvéramos', 'tinham', 'aquelas', 'fossem', 'estávamos', '%', 'nem', 'só', 'mas', 'nossas', '?', 'aquele', 'estar', 'aquela', 'sua', 'são', 'este', 'ele', 'esta', 'seu', 'estou', 'está', 'depois', 'os', '=', 'minhas', 'nós', 'fora', 'seria', 'mesmo', 'por', 'estivera', 'lhe', 'houvemos', 'houvermos', 'eram', 'como', 'quando', 'tiverem', 'não', '+', '.', 'mais', 'estas', 'tivessem', 'hajamos', 'até', 'foram', 'aquilo', '`', 'da', '<', 'tive', 'quem', 'que', 'muito', '{', 'ela', '*', 'estiveram', 'estivessem', 'qual', 'tenho', '@', 'as', 'serei', 'vos', 'houverão', 'tiver', 'lhes', 'estivermos', 'hei', 'numa', 'estamos', '\\', 'e', 'em', 'com', 'seja', 'estiver', 'uma', 'serão', 'dos', 'tu', 'teria', 'delas', 'teve', 'foi', ',', 'esteja', 'entre', 'tivermos', 'terei', 'é', 'fôramos', 'temos', '_', 'fosse', 'tem', 'na', 'éramos', 'estejamos', 'houveremos', 'teriam', 'sejam', "'", 'também', 'tivéramos', 'essa', 'estivesse', 'minha', 'nosso', 'teremos', 'ser', '!', 'estes', 'sou', 'tenha', 'estava', 'tinha', 'seríamos', 'tivera', 'houvera'}

# %%
filtered_sentence = [w for w in word_tokens if not w in stop_words]

print(filtered_sentence)
# Out:
# ['Olá', 'Lais', 'tudo', 'bem', 'Estou', 'problemas', 'VPN']

# %%
filtered_sentences = []

# %%
for w in word_tokens:
  if w not in stop_words:
    filtered_sentences.append(w)


print(filtered_sentences)
# Out:
# ['Olá', 'Lais', 'tudo', 'bem', 'Estou', 'problemas', 'VPN']
